# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Common functions
from common_functions import reduce_mem_usage, remove_rare_records

# %%
train = pd.read_csv('data/train_data.csv')
test = pd.read_csv('data/test_data.csv')
train = reduce_mem_usage(train, verbose=True)
test = reduce_mem_usage(test, verbose=True)
# Out:
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\696475909.py:1: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('data/train_data.csv')
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\696475909.py:2: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   test = pd.read_csv('data/test_data.csv')
# Mem. usage decreased to 17354.28 Mb (13.1% reduction)
# Mem. usage decreased to 15201.62 Mb (12.9% reduction)

# %% [markdown]
# ### 1. Initial Filtering
# (1) Get only win10.0.0.0 <br>
# (2) Get only consumer devices <br>
# (3) Remove virtual machines <br>
# (4) Get only windows home edition

# %%
tr_filter_criteria = (train['OsVer'] == '10.0.0.0') & \
                     (train['SkuEdition'] == 'Home') & \
                     (train['Census_IsVirtualDevice'] != 1) & \
                     (train['Census_MDC2FormFactor'].isin(['Desktop', 'Notebook', 'AllInOne', 'PCOther', 'Convertible', \
                                                          'Detachable', 'SmallTablet', 'LargeTablet']))

t_filter_criteria = (test['OsVer'] == '10.0.0.0') & \
                    (test['SkuEdition'] == 'Home') & \
                    (test['Census_IsVirtualDevice'] != 1) & \
                    (test['Census_MDC2FormFactor'].isin(['Desktop', 'Notebook', 'AllInOne', 'PCOther', 'Convertible', \
                                                          'Detachable', 'SmallTablet', 'LargeTablet']))

train_filtered = train[tr_filter_criteria]
test_filtered = test[t_filter_criteria]

print('Train Pre-Filter:', train.shape)
print('Train Post-Filter:', train_filtered.shape)
print('Test Pre-Filter:', test.shape)
print('Test Post-Filter:', test_filtered.shape)
# Out:
# Train Pre-Filter: (8921483, 83)
# Train Post-Filter: (5354415, 83)
# Test Pre-Filter: (7853253, 82)
# Test Post-Filter: (4416597, 82)

# %% [markdown]
# #### Check the target distribution after filtering

# %%
# Seems more or less equal
print(train['HasDetections'].value_counts())
print(train_filtered['HasDetections'].value_counts())
# Out:
# HasDetections
# 0    4462591
# 1    4458892
# Name: count, dtype: int64
# HasDetections
# 0    2713221
# 1    2641194
# Name: count, dtype: int64

# %% [markdown]
# ### 2. Categorical Columns Re-Mapping

# %%
# Columns to re-map/check
obj_cols = []

for col in train_filtered.columns:
    if train_filtered[col].dtype == 'object':
        obj_cols.append(col)
        print(col)
    else:
        pass
# Out:
# MachineIdentifier
# ProductName
# EngineVersion
# AppVersion
# AvSigVersion
# Platform
# Processor
# OsVer
# OsPlatformSubRelease
# OsBuildLab
# SkuEdition
# PuaMode
# SmartScreen
# Census_MDC2FormFactor
# Census_DeviceFamily
# Census_ProcessorClass
# Census_PrimaryDiskTypeName
# Census_ChassisTypeName
# Census_PowerPlatformRoleName
# Census_InternalBatteryType
# Census_OSVersion
# Census_OSArchitecture
# Census_OSBranch
# Census_OSEdition
# Census_OSSkuName
# Census_OSInstallTypeName
# Census_OSWUAutoUpdateOptionsName
# Census_GenuineStateName
# Census_ActivationChannel
# Census_FlightRing

# %%
def show_value_counts(col):
    print(train_filtered[col].value_counts())
    print(test_filtered[col].value_counts())
    
    
def remap_col(col, map_dict):
    train_filtered[col] = train_filtered[col].map(map_dict)
    test_filtered[col] = test_filtered[col].map(map_dict)

# %%
'''
MachineIdentifier -> Can ignore its just id
ProductName -> Can consider to remove the rare records
EngineVersion -> Can consider to remove the rare records
AppVersion -> Can consider to remove the rare records
AvSigVersion -> Can consider to remove the rare records
Platform -> Useless cause we filtered this to only Win10
Processor -> Can consider to remove the rare records (arm64)
OsVer -> Useless cause we filtered this to only Win10
OsPlatformSubRelease - Ok to keep
OsBuildLab -> Can consider to remove the rare records
SkuEdition -> Useless
PuaMode -> Lots of nulls
SmartScreen -> To clean
Census_MDC2FormFactor -> Ok
Census_DeviceFamily -> Can consider to remove the rare records
Census_ProcessorClass -> Ok
Census_PrimaryDiskTypeName -> Can combine unknown/unspecified
Census_ChassisTypeName -> To clean
Census_PowerPlatformRoleName -> To clean
Census_InternalBatteryType -> To clean
Census_OSVersion -> Can consider to remove the rare records
Census_OSArchitecture -> Can consider to remove the rare records
Census_OSBranch -> Can consider to remove the rare records
Census_OSEdition -> To clean (I think this is fine actually)
Census_OSSkuName -> To clean (I think this is fine) - This is actually same as OSEdition
Census_OSInstallTypeName -> To clean (I think this is fine)
Census_OSWUAutoUpdateOptionsName -> Ok
Census_GenuineStateName -> Ok
Census_ActivationChannel -> Ok
Census_FlightRing -> Can consider to remove the rare records
'''

for col in obj_cols:
    show_value_counts(col)
# Out:
# MachineIdentifier
# 000007905a28d863f6d0d597892cd692    1
# aab22fbcacaf5c6f41627a2928236d78    1
# aab26960bed9eb54fe20fef4213d70b0    1
# aab2657c22e533935e5755a610cc8aec    1
# aab262512c74b1a0cadcd47118b89824    1
#                                    ..
# 5552cf8a5e2e2481a8fc6568d7b8fd01    1
# 5552cd8d33e5c1e304304109051cd43c    1
# 5552cbd1dbae465c429cebf5fedf0e6a    1
# 5552ca5bb20c1a7a6e7f034df151b9c0    1
# ffffff75ba4f33d938ccfdb148b8ea16    1
# Name: count, Length: 5354415, dtype: int64
# MachineIdentifier
# 0000010489e3af074adeac69c53e555e    1
# aa9bd49b67993a49e63a2a0bc826b08e    1
# aa9ba8da8ae4177dd4cc49fbe32fce0a    1
# aa9bac7b4fa13402f8f552d66e264109    1
# aa9bb2ea2caeacec5fb8f6491bb0faaf    1
#                                    ..
# 554c9b91516caf0c2f6ffca0e95a7d65    1
# 554c9cbc9d72d01775401a33838ad795    1
# 554c9d5fc404e6b56d1666889d450b94    1
# 554ca09623888fff4b6648f04f727a07    1
# fffffbd305a90eb0f93ee4f30a39c736    1
# Name: count, Length: 4416597, dtype: int64
# ProductName
# win8defender     5353904
# mse                  510
# mseprerelease          1
# Name: count, dtype: int64
# ProductName
# win8defender    4416231
# mse                 365
# fep                   1
# Name: count, dtype: int64
# EngineVersion
# 1.1.15200.1    2253893
# 1.1.15100.1    2188264
# 1.1.15000.2     174359
# 1.1.14901.4     140174
# 1.1.14600.4      98928
#                 ...
# 1.1.12300.0          2
# 1.1.13503.0          2
# 1.1.13301.0          2
# 1.1.11400.0          1
# 1.1.12802.0          1
# Name: count, Length: 64, dtype: int64
# EngineVersion
# 1.1.15300.6    1821326
# 1.1.15400.4    1148042
# 1.1.15400.5     709116
# 1.1.15200.1     242619
# 1.1.15100.1     103213
#                 ...
# 1.1.13503.0          2
# 1.1.13102.0          2
# 1.1.12205.0          1
# 1.1.12300.0          1
# 1.1.11400.0          1
# Name: count, Length: 63, dtype: int64
# AppVersion
# 4.18.1807.18075     3126436
# 4.18.1806.18062      540774
# 4.12.16299.15        249546
# 4.16.17656.18052     158676
# 4.13.17134.1         154349
#                      ...
# 4.6.305.0                 1
# 4.17.17686.1004           1
# 4.13.17134.226            1
# 4.15.17643.1000           1
# 4.13.17604.1000           1
# Name: count, Length: 89, dtype: int64
# AppVersion
# 4.18.1809.2         1629359
# 4.18.1810.5         1109464
# 4.18.1807.18075      450133
# 4.12.16299.15        162998
# 4.9.10586.1106       120379
#                      ...
# 4.12.16299.0              1
# 4.9.10586.461             1
# 4.8.10240.16425           1
# 4.13.17634.1000           1
# 4.12.17007.18021          1
# Name: count, Length: 94, dtype: int64
# AvSigVersion
# 1.273.1420.0    58438
# 1.263.48.0      57260
# 1.275.1140.0    55568
# 1.275.727.0     55189
# 1.251.42.0      52458
#                 ...
# 1.223.2670.0        1
# 1.207.1058.0        1
# 1.225.233.0         1
# 1.223.755.0         1
# 1.223.1075.0        1
# Name: count, Length: 8411, dtype: int64
# AvSigVersion
# 1.263.48.0      69859
# 1.277.515.0     46828
# 1.251.42.0      42680
# 1.279.102.0     41958
# 1.279.32.0      38489
#                 ...
# 1.225.598.0         1
# 1.225.4034.0        1
# 1.237.924.0         1
# 1.225.583.0         1
# 1.227.291.0         1
# Name: count, Length: 9152, dtype: int64
# Platform
# windows10    5354415
# Name: count, dtype: int64
# Platform
# windows10    4416597
# Name: count, dtype: int64
# Processor
# x64      4974679
# x86       379718
# arm64         18
# Name: count, dtype: int64
# Processor
# x64      4111881
# x86       304706
# arm64         10
# Name: count, dtype: int64
# OsVer
# 10.0.0.0    5354415
# Name: count, dtype: int64
# OsVer
# 10.0.0.0    4416597
# Name: count, dtype: int64
# OsPlatformSubRelease
# rs4       2168701
# rs3       1691661
# rs2        569034
# rs1        531685
# th2        283697
# th1        101458
# prers5       8179
# Name: count, dtype: int64
# OsPlatformSubRelease
# rs4       2082518
# rs3       1088916
# rs2        413447
# rs1        385753
# th2        225889
# prers5     131979
# th1         88095
# Name: count, dtype: int64
# OsBuildLab
# 17134.1.amd64fre.rs4_release.180410-1804                     2068939
# 16299.431.amd64fre.rs3_release_svc_escrow.180502-1908         920114
# 16299.15.amd64fre.rs3_release.170928-1534                     624812
# 15063.0.amd64fre.rs2_release.170317-1834                      534115
# 14393.2189.amd64fre.rs1_release.180329-1711                   153754
#                                                               ...
# 17686.1004.amd64fre.rs_onecore_sigma_grfx_dev.180604-1518          1
# 14230.1944.amd64fre.rs1_release.171284-2100                        1
# 17618.1000.x86fre.rs_prerelease.180302-1651                        1
# 14393.1797.amd64fre.rs1_release_inmarket_aim.171027-1738           1
# 17723.1000.x86fre.rs5_release.180720-1452                          1
# Name: count, Length: 280, dtype: int64
# OsBuildLab
# 17134.1.amd64fre.rs4_release.180410-1804                 1982249
# 16299.15.amd64fre.rs3_release.170928-1534                 443767
# 16299.431.amd64fre.rs3_release_svc_escrow.180502-1908     400618
# 15063.0.amd64fre.rs2_release.170317-1834                  388865
# 16299.637.amd64fre.rs3_release_svc.180808-1748            168196
#                                                           ...
# 14393.1532.x86fre.rs1_release_d.170711-1840                    1
# 14218.1944.amd64fre.rs1_release.171165-2100                    1
# 14421.1944.amd64fre.rs1_release.171268-2100                    1
# 18219.1000.amd64fre.rs_prerelease.180810-1721                  1
# 14393.1670.amd64fre.rs1_release_inmarket.170821-1825           1
# Name: count, Length: 298, dtype: int64
# SkuEdition
# Home    5354415
# Name: count, dtype: int64
# SkuEdition
# Home    4416597
# Name: count, dtype: int64
# PuaMode
# on    938
# Name: count, dtype: int64
# PuaMode
# on       936
# audit      3
# Name: count, dtype: int64
# SmartScreen
# RequireAdmin    2783655
# ExistsNotSet     609395
# Off               89139
# Warn              74301
# Prompt            18408
# Block             14437
# On                  717
# off                 540
# &#x02;              150
# on                   43
# &#x01;               31
# requireadmin          3
# Promt                 1
# OFF                   1
# Enabled               1
# prompt                1
# warn                  1
# 00000000              1
# requireAdmin          1
# Name: count, dtype: int64
# SmartScreen
# RequireAdmin    2113669
# ExistsNotSet     320408
# Off               71756
# Warn              68262
# Prompt            14909
# Block             13339
# On                  794
# off                 773
# &#x02;              115
# on                   37
# &#x01;               34
# requireadmin          7
# OFF                   3
# 0                     3
# Promprt               1
# warn                  1
# of                    1
# BLOCK                 1
# Name: count, dtype: int64
# Census_MDC2FormFactor
# Notebook       3837429
# Desktop         605744
# Convertible     332449
# AllInOne        203123
# Detachable      188151
# PCOther         106337
# LargeTablet      52421
# SmallTablet      28761
# Name: count, dtype: int64
# Census_MDC2FormFactor
# Notebook       3145847
# Desktop         527756
# Convertible     269491
# AllInOne        165876
# Detachable      154327
# PCOther          91149
# LargeTablet      42706
# SmallTablet      19445
# Name: count, dtype: int64
# Census_DeviceFamily
# Windows.Desktop    5354404
# Windows                  9
# Windows.Server           2
# Name: count, dtype: int64
# Census_DeviceFamily
# Windows.Desktop    4416579
# Windows                 10
# Windows.Server           8
# Name: count, dtype: int64
# Census_ProcessorClass
# mid     3868
# low     1883
# high    1048
# Name: count, dtype: int64
# Census_ProcessorClass
# mid     2070
# low     1052
# high     543
# Name: count, dtype: int64
# Census_PrimaryDiskTypeName
# HDD            3731363
# SSD            1447434
# UNKNOWN         100634
# Unspecified      74965
# Name: count, dtype: int64
# Census_PrimaryDiskTypeName
# HDD            2963247
# SSD            1298926
# UNKNOWN          97998
# Unspecified      56416
# Name: count, dtype: int64
# Census_ChassisTypeName
# Notebook               3742657
# Desktop                 685334
# Laptop                  334526
# Portable                201799
# AllinOne                149118
# Convertible              71848
# Detachable               43982
# UNKNOWN                  39768
# HandHeld                 34171
# Tablet                   11005
# Other                    10437
# MiniTower                 9551
# LowProfileDesktop         7379
# Unknown                   4581
# SpaceSaving               3726
# Tower                      911
# MiniPC                     705
# BusExpansionChassis        700
# SubNotebook                658
# LunchBox                   565
# MainServerChassis          550
# 30                         200
# StickPC                    116
# 0                           64
# RackMountChassis            11
# SubChassis                  11
# MultisystemChassis          10
# 32                           8
# 31                           7
# 35                           4
# 36                           3
# SealedCasePC                 2
# 82                           1
# DockingStation               1
# 25                           1
# 49                           1
# CompactPCI                   1
# 88                           1
# 44                           1
# Name: count, dtype: int64
# Census_ChassisTypeName
# Notebook               3068196
# Desktop                 588330
# Laptop                  273295
# Portable                162039
# AllinOne                122891
# Convertible              66916
# Detachable               36264
# UNKNOWN                  27248
# HandHeld                 26876
# Tablet                    9020
# MiniTower                 8905
# Other                     8593
# LowProfileDesktop         6535
# Unknown                   3645
# SpaceSaving               3539
# Tower                      864
# MiniPC                     750
# SubNotebook                690
# BusExpansionChassis        654
# MainServerChassis          590
# LunchBox                   524
# StickPC                    100
# 30                          46
# 0                           43
# RackMountChassis            13
# SubChassis                   9
# DockingStation               7
# MultisystemChassis           4
# PizzaBox                     2
# 36                           2
# 32                           2
# SealedCasePC                 1
# 35                           1
# PeripheralChassis            1
# Name: count, dtype: int64
# Census_PowerPlatformRoleName
# Mobile               4211119
# Desktop               742449
# Slate                 352697
# Workstation            28525
# UNKNOWN                 9746
# SOHOServer              6054
# AppliancePC             3729
# EnterpriseServer          91
# PerformanceServer          5
# Name: count, dtype: int64
# Census_PowerPlatformRoleName
# Mobile               3450897
# Desktop               638102
# Slate                 286597
# Workstation            24842
# UNKNOWN                 7454
# SOHOServer              5680
# AppliancePC             2920
# EnterpriseServer         100
# PerformanceServer          4
# Unspecified                1
# Name: count, dtype: int64
# Census_InternalBatteryType
# lion        1360272
# li-i         164996
# #             46646
# lip           39510
# liio          22411
# li p           6929
# li             4081
# nimh           2434
# pbac            986
# real            599
# lgi0            262
# unkn            213
# lipo            139
# 4cel            120
# lhp0             98
# ithi             70
# batt             56
# bad              16
# ca48             16
# lipp              7
# lit               6
# ots0              4
# lai0              3
# ÿÿÿÿ              3
# li-p              3
# lgs0              2
# 4lio              2
# h00j              2
# pad0              1
# l&#TAB#          1
# 8                 1
# ip               1
# ram               1
# lio              1
# 3500              1
# li?               1
# ion              1
# li-l              1
# @i              1
# l                1
# lgl0              1
# ˙˙˙              1
# 0x0b              1
# sail              1
# 0ts0              1
# liÿÿ              1
# Name: count, dtype: int64
# Census_InternalBatteryType
# lion     938235
# li-i     116159
# #         38124
# lip       28032
# liio      16923
# li p       5005
# li         3003
# nimh       1896
# pbac        692
# real        438
# lgi0        144
# lipo        127
# unkn        125
# 4cel         78
# batt         56
# ithi         47
# lhp0         44
# ca48         12
# bad          12
# lit           6
# ram           6
# 4lio          4
# ots0          3
# lio           2
# li-p          2
# l?           2
# ÿÿÿÿ          1
# 0x0b          1
# 2             1
# h00j          1
# lipp          1
# pad0          1
# loÿÿ          1
# #TAB#         1
# 9ion          1
# Name: count, dtype: int64
# Census_OSVersion
# 10.0.17134.228     775655
# 10.0.17134.165     488465
# 10.0.16299.431     396370
# 10.0.17134.285     262901
# 10.0.16299.547     249790
#                     ...
# 10.0.17711.1000         1
# 10.0.14936.1000         1
# 6.2.9200.17617          1
# 10.0.17063.1000         1
# 10.0.16241.1001         1
# Name: count, Length: 298, dtype: int64
# Census_OSVersion
# 10.0.17134.345     752583
# 10.0.17134.285     382216
# 10.0.17134.407     236290
# 10.0.16299.431     207023
# 10.0.17134.286     206109
#                     ...
# 10.0.16353.1000         1
# 10.0.15063.1446         1
# 10.0.14218.376          1
# 10.0.14421.345          1
# 10.0.14393.1670         1
# Name: count, Length: 316, dtype: int64
# Census_OSArchitecture
# amd64    4974923
# x86       379474
# arm64         18
# Name: count, dtype: int64
# Census_OSArchitecture
# amd64    4112138
# x86       304449
# arm64         10
# Name: count, dtype: int64
# Census_OSBranch
# rs4_release                  2224866
# rs3_release_svc_escrow        880847
# rs3_release                   757667
# rs2_release                   567398
# rs1_release                   528360
# th2_release_sec               192686
# th2_release                    90148
# th1_st1                        73092
# th1                            28024
# rs5_release                     5877
# rs3_release_svc_escrow_im       3110
# rs_prerelease_flt               1251
# rs_prerelease                   1079
# winblue_ltsb_escrow                5
# winblue_ltsb                       2
# rs1_release_sec                    1
# win8_gdr                           1
# win8_ldr                           1
# Name: count, dtype: int64
# Census_OSBranch
# rs4_release                  2138692
# rs3_release                   655932
# rs2_release                   412100
# rs1_release                   382607
# rs3_release_svc_escrow        378779
# th2_release_sec               152756
# rs5_release                   130115
# th2_release                    72078
# th1_st1                        65141
# th1                            22929
# rs_prerelease                   3236
# rs3_release_svc_escrow_im       2105
# rs_prerelease_flt                112
# winblue_ltsb                       7
# rs1_release_inmarket               3
# winblue_ltsb_escrow                2
# rs5_release_sigma                  1
# rs2_release_svc_d                  1
# win7sp1_ldr                        1
# Name: count, dtype: int64
# Census_OSEdition
# Core                           3318355
# CoreSingleLanguage             1869898
# CoreCountrySpecific             158130
# CoreN                             4247
# Professional                      3474
# Education                          124
# Enterprise                          87
# ProfessionalN                       49
# Cloud                               11
# ProfessionalWorkstation             11
# EducationN                          10
# EnterpriseS                          8
# ProfessionalEducation                5
# ServerStandard                       2
# ProfessionalCountrySpecific          2
# HomePremium                          1
# ServerRdsh                           1
# Name: count, dtype: int64
# Census_OSEdition
# Core                           2684781
# CoreSingleLanguage             1551388
# CoreCountrySpecific             171625
# CoreN                             4187
# Professional                      4148
# Education                          168
# Enterprise                         124
# ProfessionalN                       58
# EnterpriseS                         53
# ProfessionalWorkstation             18
# ProfessionalEducation               15
# Cloud                                9
# ServerStandard                       5
# ServerRdsh                           4
# EnterpriseN                          3
# EducationN                           3
# ProfessionalWorkstationN             2
# ServerDatacenter                     2
# ServerSolution                       1
# ProfessionalCountrySpecific          1
# EnterpriseSN                         1
# HomePremium                          1
# Name: count, dtype: int64
# Census_OSSkuName
# CORE                    3318510
# CORE_SINGLELANGUAGE     1869792
# CORE_COUNTRYSPECIFIC     158071
# CORE_N                     4246
# PROFESSIONAL               3468
# EDUCATION                   129
# ENTERPRISE                  103
# PROFESSIONAL_N               46
# UNLICENSED                   12
# PRO_WORKSTATION              11
# ENTERPRISE_S                  7
# EDUCATION_N                   7
# CLOUD                         7
# STANDARD_SERVER               2
# PRO_CHINA                     2
# SERVERRDSH                    1
# UNDEFINED                     1
# Name: count, dtype: int64
# Census_OSSkuName
# CORE                    2684860
# CORE_SINGLELANGUAGE     1551322
# CORE_COUNTRYSPECIFIC     171532
# PROFESSIONAL               4195
# CORE_N                     4189
# EDUCATION                   176
# ENTERPRISE                  151
# PROFESSIONAL_N               56
# ENTERPRISE_S                 53
# PRO_WORKSTATION              18
# UNLICENSED                   12
# CLOUD                         8
# STANDARD_SERVER               5
# SERVERRDSH                    4
# EDUCATION_N                   3
# ENTERPRISE_N                  3
# PRO_WORKSTATION_N             2
# DATACENTER_SERVER             2
# PRO_FOR_EDUCATION             1
# SB_SOLUTION_SERVER            1
# PRO_CHINA                     1
# ENTERPRISE_S_N                1
# HOME_PREMIUM                  1
# UNDEFINED                     1
# Name: count, dtype: int64
# Census_OSInstallTypeName
# UUPUpgrade        1538735
# Update             966536
# Upgrade            787709
# Other              680500
# IBSClean           641624
# Reset              509234
# Refresh            150987
# CleanPCRefresh      40046
# Clean               39044
# Name: count, dtype: int64
# Census_OSInstallTypeName
# UUPUpgrade        1055350
# IBSClean           729286
# Update             673580
# Other              630956
# Upgrade            569770
# Reset              474218
# Refresh            187665
# CleanPCRefresh      54210
# Clean               41562
# Name: count, dtype: int64
# Census_OSWUAutoUpdateOptionsName
# FullAuto                                 2143395
# Notify                                   1472770
# UNKNOWN                                  1463696
# AutoInstallAndRebootAtMaintenanceTime     274554
# Name: count, dtype: int64
# Census_OSWUAutoUpdateOptionsName
# FullAuto                                 2211399
# UNKNOWN                                  1160490
# Notify                                    891750
# AutoInstallAndRebootAtMaintenanceTime     152958
# Name: count, dtype: int64
# Census_GenuineStateName
# IS_GENUINE         5083944
# INVALID_LICENSE     163945
# OFFLINE             103053
# UNKNOWN               3473
# Name: count, dtype: int64
# Census_GenuineStateName
# IS_GENUINE         4153632
# INVALID_LICENSE     163008
# OFFLINE              98004
# UNKNOWN               1953
# Name: count, dtype: int64
# Census_ActivationChannel
# OEM:DM         2900119
# Retail         2253463
# OEM:NONSLP      178127
# Volume:GVLK      22706
# Name: count, dtype: int64
# Census_ActivationChannel
# OEM:DM         2385592
# Retail         1849734
# OEM:NONSLP      146683
# Volume:GVLK      34588
# Name: count, dtype: int64
# Census_FlightRing
# Retail      5090210
# Unknown      148170
# NOT_SET      101931
# WIS            4421
# RP             4359
# WIF            3805
# Disabled       1516
# OSG               3
# Name: count, dtype: int64
# Census_FlightRing
# Retail      4188446
# Unknown      117302
# NOT_SET       92770
# RP             8519
# WIS            4124
# WIF            4030
# Disabled       1405
# OSG               1
# Name: count, dtype: int64

# %%
'''
Explanation of Values

1. &#x01;
Hexadecimal 0x01 (decimal 1):
This typically means enabled or on.
In the context of SmartScreen settings, it likely indicates that a specific feature or protection level is turned on.

2. &#x02;
Hexadecimal 0x02 (decimal 2):
This value might represent a different state or level of protection compared to 0x01.
It could be used to signify a specific mode, such as intermediate protection or a secondary feature being enabled.

3. 00000000
Hexadecimal 0x00000000 (decimal 0):
This typically means disabled or off.
In the context of SmartScreen settings, it likely indicates that a specific feature or protection level is turned off.
'''

smart_screen_remap = {'RequireAdmin'  : 'RequireAdmin',
                      'ExistsNotSet'  : 'ExistNotSet', 
                      'Off'           : 'Off',
                      'Warn'          : 'Warn',
                      'Prompt'        : 'Prompt',
                      'Block'         : 'Block',
                      'On'            : 'On',
                      'off'           : 'Off',
                      '&#x02;'        : 'On',
                      'on'            : 'On',
                      '&#x01;'        : 'On',
                      'requireadmin'  : 'RequireAdmin', 
                      'Promt'         : 'Prompt',
                      'OFF'           : 'Off',
                      'Enabled'       : 'On',
                      'prompt'        : 'Prompt',
                      'warn'          : 'Warn',
                      '00000000'      : 'Off',
                      'requireAdmin'  : 'RequireAdmin'
                     }

show_value_counts('SmartScreen')
remap_col('SmartScreen', smart_screen_remap)
show_value_counts('SmartScreen')
# Out:
# SmartScreen
# RequireAdmin    2783655
# ExistsNotSet     609395
# Off               89139
# Warn              74301
# Prompt            18408
# Block             14437
# On                  717
# off                 540
# &#x02;              150
# on                   43
# &#x01;               31
# requireadmin          3
# Promt                 1
# OFF                   1
# Enabled               1
# prompt                1
# warn                  1
# 00000000              1
# requireAdmin          1
# Name: count, dtype: int64
# SmartScreen
# RequireAdmin    2113669
# ExistsNotSet     320408
# Off               71756
# Warn              68262
# Prompt            14909
# Block             13339
# On                  794
# off                 773
# &#x02;              115
# on                   37
# &#x01;               34
# requireadmin          7
# OFF                   3
# 0                     3
# Promprt               1
# warn                  1
# of                    1
# BLOCK                 1
# Name: count, dtype: int64
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\1324870777.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_filtered[col] = train_filtered[col].map(map_dict)
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\1324870777.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_filtered[col] = test_filtered[col].map(map_dict)
# SmartScreen
# RequireAdmin    2783659
# ExistNotSet      609395
# Off               89681
# Warn              74302
# Prompt            18410
# Block             14437
# On                  942
# Name: count, dtype: int64
# SmartScreen
# RequireAdmin    2113676
# ExistNotSet      320408
# Off               72532
# Warn              68263
# Prompt            14909
# Block             13339
# On                  980
# Name: count, dtype: int64

# %%
chassis_type_remap = {'Notebook'               : 'Notebook',
                      'Desktop'                : 'Desktop',
                      'Laptop'                 : 'Notebook',
                      'Portable'               : 'Portable',
                      'AllinOne'               : 'AllInOne',
                      'Convertible'            : 'Convertible',
                      'Detachable'             : 'Detachable',
                      'UNKNOWN'                : 'Unknown',
                      'HandHeld'               : 'Handheld',
                      'Tablet'                 : 'Tablet',
                      'Other'                  : 'Other',
                      'MiniTower'              : 'TowerDesktop',
                      'LowProfileDesktop'      : 'Desktop',
                      'Unknown'                : 'Unknown',
                      'SpaceSaving'            : 'MiniDesktop',
                      'Tower'                  : 'TowerDesktop',
                      'MiniPC'                 : 'MiniDesktop',
                      'BusExpansionChassis'    : 'Chassis',
                      'SubNotebook'            : 'Portable',
                      'LunchBox'               : 'MiniDesktop',
                      'MainServerChassis'      : 'Chassis',
                      '30'                     : 'Unknown',
                      'StickPC'                : 'MiniDesktop',
                      '0'                      : 'Unknown',
                      'RackMountChassis'       : 'Chassis',
                      'SubChassis'             : 'Chassis',
                      'MultisystemChassis'     : 'Chassis',
                      '32'                     : 'Unknown',
                      '31'                     : 'Unknown',
                      '35'                     : 'Unknown',
                      '36'                     : 'Unknown',
                      'SealedCasePC'           : 'Desktop',
                      '82'                     : 'Unknown',
                      'DockingStation'         : 'Chassis',
                      '25'                     : 'Unknown',
                      '49'                     : 'Unknown',
                      'CompactPCI'             : 'MiniDesktop',
                      '88'                     : 'Unknown',
                      '44'                     : 'Unknown'
                     }

show_value_counts('Census_ChassisTypeName')
remap_col('Census_ChassisTypeName', chassis_type_remap)
show_value_counts('Census_ChassisTypeName')
# Out:
# Census_ChassisTypeName
# Notebook               3742657
# Desktop                 685334
# Laptop                  334526
# Portable                201799
# AllinOne                149118
# Convertible              71848
# Detachable               43982
# UNKNOWN                  39768
# HandHeld                 34171
# Tablet                   11005
# Other                    10437
# MiniTower                 9551
# LowProfileDesktop         7379
# Unknown                   4581
# SpaceSaving               3726
# Tower                      911
# MiniPC                     705
# BusExpansionChassis        700
# SubNotebook                658
# LunchBox                   565
# MainServerChassis          550
# 30                         200
# StickPC                    116
# 0                           64
# RackMountChassis            11
# SubChassis                  11
# MultisystemChassis          10
# 32                           8
# 31                           7
# 35                           4
# 36                           3
# SealedCasePC                 2
# 82                           1
# DockingStation               1
# 25                           1
# 49                           1
# CompactPCI                   1
# 88                           1
# 44                           1
# Name: count, dtype: int64
# Census_ChassisTypeName
# Notebook               3068196
# Desktop                 588330
# Laptop                  273295
# Portable                162039
# AllinOne                122891
# Convertible              66916
# Detachable               36264
# UNKNOWN                  27248
# HandHeld                 26876
# Tablet                    9020
# MiniTower                 8905
# Other                     8593
# LowProfileDesktop         6535
# Unknown                   3645
# SpaceSaving               3539
# Tower                      864
# MiniPC                     750
# SubNotebook                690
# BusExpansionChassis        654
# MainServerChassis          590
# LunchBox                   524
# StickPC                    100
# 30                          46
# 0                           43
# RackMountChassis            13
# SubChassis                   9
# DockingStation               7
# MultisystemChassis           4
# PizzaBox                     2
# 36                           2
# 32                           2
# SealedCasePC                 1
# 35                           1
# PeripheralChassis            1
# Name: count, dtype: int64
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\1324870777.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_filtered[col] = train_filtered[col].map(map_dict)
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\1324870777.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_filtered[col] = test_filtered[col].map(map_dict)
# Census_ChassisTypeName
# Notebook        4077183
# Desktop          692715
# Portable         202457
# AllInOne         149118
# Convertible       71848
# Unknown           44640
# Detachable        43982
# Handheld          34171
# Tablet            11005
# TowerDesktop      10462
# Other             10437
# MiniDesktop        5113
# Chassis            1283
# Name: count, dtype: int64
# Census_ChassisTypeName
# Notebook        3341491
# Desktop          594866
# Portable         162729
# AllInOne         122891
# Convertible       66916
# Detachable        36264
# Unknown           30987
# Handheld          26876
# TowerDesktop       9769
# Tablet             9020
# Other              8593
# MiniDesktop        4913
# Chassis            1277
# Name: count, dtype: int64

# %%
power_platform_remap = {'Mobile'              : 'Mobile',
                        'Desktop'             : 'Desktop',
                        'Slate'               : 'Slate',
                        'Workstation'         : 'Workstation',
                        'UNKNOWN'             : 'Unknown',
                        'SOHOServer'          : 'Small/Home Office Server',
                        'AppliancePC'         : 'Appliance',
                        'EnterpriseServer'    : 'Enterprise Server',
                        'PerformanceServer'   : 'Enterprise Server',
                        'Unspecified'         : 'Unknown'
                       }

show_value_counts('Census_PowerPlatformRoleName')
remap_col('Census_PowerPlatformRoleName', power_platform_remap)
show_value_counts('Census_PowerPlatformRoleName')
# Out:
# Census_PowerPlatformRoleName
# Mobile               4211119
# Desktop               742449
# Slate                 352697
# Workstation            28525
# UNKNOWN                 9746
# SOHOServer              6054
# AppliancePC             3729
# EnterpriseServer          91
# PerformanceServer          5
# Name: count, dtype: int64
# Census_PowerPlatformRoleName
# Mobile               3450897
# Desktop               638102
# Slate                 286597
# Workstation            24842
# UNKNOWN                 7454
# SOHOServer              5680
# AppliancePC             2920
# EnterpriseServer         100
# PerformanceServer          4
# Unspecified                1
# Name: count, dtype: int64
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\1324870777.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_filtered[col] = train_filtered[col].map(map_dict)
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\1324870777.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_filtered[col] = test_filtered[col].map(map_dict)
# Census_PowerPlatformRoleName
# Mobile                      4211119
# Desktop                      742449
# Slate                        352697
# Workstation                   28525
# Unknown                        9746
# Small/Home Office Server       6054
# Appliance                      3729
# Enterprise Server                96
# Name: count, dtype: int64
# Census_PowerPlatformRoleName
# Mobile                      3450897
# Desktop                      638102
# Slate                        286597
# Workstation                   24842
# Unknown                        7455
# Small/Home Office Server       5680
# Appliance                      2920
# Enterprise Server               104
# Name: count, dtype: int64

# %%
train_filtered[train_filtered['Census_InternalBatteryType'] == 'unkn']['HasDetections'].value_counts()
# Out:
# HasDetections
# 0    108
# 1    105
# Name: count, dtype: int64

# %%
batt_type_remap = {'lion'     : 'Lithium Ion',
                   'li-i'     : 'Lithium Ion',
                   '#'        : 'Unknown', # About 50/50 for target
                   'lip'      : 'Lithium Polymer',
                   'liio'     : 'Lithium Ion',
                   'li p'     : 'Lithium Polymer',
                   'li'       : 'Lithium Ion',
                   'nimh'     : 'Nickel Metal Hydride',
                   'pbac'     : 'Lead Acid',
                   'real'     : 'Unknown',
                   'lgi0'     : 'Lithium Ion',
                   'unkn'     : 'Unknown', # About 50/50 for target
                   'lipo'     : 'Lithium Polymer',
                   '4cel'     : '4-Cell',
                   'lhp0'     : 'Lithium Ion',
                   'ithi'     : 'Lithium Ion',
                   'batt'     : 'Unknown',
                   'bad'      : 'Unknown',
                   'ca48'     : 'Unknown',
                   'lipp'     : 'Lithium Polymer',
                   'lit'      : 'Lithium Ion',
                   'ots0'     : 'Unknown',
                   'lai0'     : 'Unknown',
                   'ÿÿÿÿ'     : 'Unknown',
                   'li-p'     : 'Lithium Polymer',
                   'lgs0'     : 'Unknown',
                   '4lio'     : 'Lithium Ion',
                   'h00j'     : 'Unknown',
                   'pad0'     : 'Unknown',
                   'l&#TAB#' : 'Unknown',
                   '8'        : 'Unknown',
                   'ip'      : 'Unknown',
                   'ram'      : 'Unknown',
                   'lio'     : 'Lithium Ion',
                   '3500'     : 'Unknown',
                   'li?'      : 'Lithium Ion',
                   'ion'     : 'Lithium Ion',
                   'li-l'     : 'Lithium Ion',
                   '@i'     : 'Unknown',
                   'l'       : 'Unknown',
                   'lgl0'     : 'Unknown',
                   '˙˙˙'     : 'Unknown',
                   '0x0b'     : 'Unknown',
                   'sail'     : 'Unknown',
                   '0ts0'     : 'Unknown',
                   'liÿÿ'     : 'Unknown'
                  }

show_value_counts('Census_InternalBatteryType')
remap_col('Census_InternalBatteryType', batt_type_remap)
show_value_counts('Census_InternalBatteryType')
# Out:
# Census_InternalBatteryType
# lion        1360272
# li-i         164996
# #             46646
# lip           39510
# liio          22411
# li p           6929
# li             4081
# nimh           2434
# pbac            986
# real            599
# lgi0            262
# unkn            213
# lipo            139
# 4cel            120
# lhp0             98
# ithi             70
# batt             56
# bad              16
# ca48             16
# lipp              7
# lit               6
# ots0              4
# lai0              3
# ÿÿÿÿ              3
# li-p              3
# lgs0              2
# 4lio              2
# h00j              2
# pad0              1
# l&#TAB#          1
# 8                 1
# ip               1
# ram               1
# lio              1
# 3500              1
# li?               1
# ion              1
# li-l              1
# @i              1
# l                1
# lgl0              1
# ˙˙˙              1
# 0x0b              1
# sail              1
# 0ts0              1
# liÿÿ              1
# Name: count, dtype: int64
# Census_InternalBatteryType
# lion     938235
# li-i     116159
# #         38124
# lip       28032
# liio      16923
# li p       5005
# li         3003
# nimh       1896
# pbac        692
# real        438
# lgi0        144
# lipo        127
# unkn        125
# 4cel         78
# batt         56
# ithi         47
# lhp0         44
# ca48         12
# bad          12
# lit           6
# ram           6
# 4lio          4
# ots0          3
# lio           2
# li-p          2
# l?           2
# ÿÿÿÿ          1
# 0x0b          1
# 2             1
# h00j          1
# lipp          1
# pad0          1
# loÿÿ          1
# #TAB#         1
# 9ion          1
# Name: count, dtype: int64
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\1324870777.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_filtered[col] = train_filtered[col].map(map_dict)
# C:\Users\leongkw\AppData\Local\Temp\ipykernel_15556\1324870777.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_filtered[col] = test_filtered[col].map(map_dict)
# Census_InternalBatteryType
# Lithium Ion             1552202
# Unknown                   47574
# Lithium Polymer           46588
# Nickel Metal Hydride       2434
# Lead Acid                   986
# 4-Cell                      120
# Name: count, dtype: int64
# Census_InternalBatteryType
# Lithium Ion             1074565
# Unknown                   38780
# Lithium Polymer           33167
# Nickel Metal Hydride       1896
# Lead Acid                   692
# 4-Cell                       78
# Name: count, dtype: int64

# %%
non_obj_cols = []

for col in train_filtered.columns:
    if col not in obj_cols:
        non_obj_cols.append(col)
        print(col)
# Out:
# IsBeta
# RtpStateBitfield
# IsSxsPassiveMode
# DefaultBrowsersIdentifier
# AVProductStatesIdentifier
# AVProductsInstalled
# AVProductsEnabled
# HasTpm
# CountryIdentifier
# CityIdentifier
# OrganizationIdentifier
# GeoNameIdentifier
# LocaleEnglishNameIdentifier
# OsBuild
# OsSuite
# IsProtected
# AutoSampleOptIn
# SMode
# IeVerIdentifier
# Firewall
# UacLuaenable
# Census_OEMNameIdentifier
# Census_OEMModelIdentifier
# Census_ProcessorCoreCount
# Census_ProcessorManufacturerIdentifier
# Census_ProcessorModelIdentifier
# Census_PrimaryDiskTotalCapacity
# Census_SystemVolumeTotalCapacity
# Census_HasOpticalDiskDrive
# Census_TotalPhysicalRAM
# Census_InternalPrimaryDiagonalDisplaySizeInInches
# Census_InternalPrimaryDisplayResolutionHorizontal
# Census_InternalPrimaryDisplayResolutionVertical
# Census_InternalBatteryNumberOfCharges
# Census_OSBuildNumber
# Census_OSBuildRevision
# Census_OSInstallLanguageIdentifier
# Census_OSUILocaleIdentifier
# Census_IsPortableOperatingSystem
# Census_IsFlightingInternal
# Census_IsFlightsDisabled
# Census_ThresholdOptIn
# Census_FirmwareManufacturerIdentifier
# Census_FirmwareVersionIdentifier
# Census_IsSecureBootEnabled
# Census_IsWIMBootEnabled
# Census_IsVirtualDevice
# Census_IsTouchEnabled
# Census_IsPenCapable
# Census_IsAlwaysOnAlwaysConnectedCapable
# Wdft_IsGamer
# Wdft_RegionIdentifier
# HasDetections

# %%
'''
IsBeta -> Can remove this column (Binary) V v skewed distribution
RtpStateBitfield -> Ok. (Categorical)
IsSxsPassiveMode -> Ok (Binary)
DefaultBrowsersIdentifier -> Can consider removing rare records
AVProductStatesIdentifier -> Can consider removing rare records
AVProductsInstalled -> Ok (Integer)
AVProductsEnabled -> Ok (Integer)
HasTpm -> Ok (Binary)
CountryIdentifier -> Can consider dimension reduction
CityIdentifier -> Can consider removing rare records
OrganizationIdentifier -> Can consider removing rare records
GeoNameIdentifier -> Can consider removing rare records
LocaleEnglishNameIdentifier -> Can consider removing rare records
OsBuild -> Can consider removing rare records
OsSuite -> Can remove this column -> V v skewed distribution
IsProtected -> Ok (Binary)
AutoSampleOptIn -> Can remove this column (Binary) V v skewed distribution
SMode -> Can remove this column (Binary) V v skewed distribution
IeVerIdentifier -> Can consider removing rare records
Firewall -> Ok (Binary)
UacLuaenable -> Can consider removing rare records 
Census_OEMNameIdentifier -> Can consider removing rare records
Census_OEMModelIdentifier -> Can consider removing rare records
Census_ProcessorCoreCount -> Can consider binning
Census_ProcessorManufacturerIdentifier -> Can consider removing rare records
Census_ProcessorModelIdentifier -> Can consider removing rare records
Census_PrimaryDiskTotalCapacity -> Can consider binning
Census_SystemVolumeTotalCapacity -> Can consider binning
Census_HasOpticalDiskDrive -> Binary
Census_TotalPhysicalRAM -> Can consider binning
Census_InternalPrimaryDiagonalDisplaySizeInInches -> Can consider binning
Census_InternalPrimaryDisplayResolutionHorizontal -> Can consider binning
Census_InternalPrimaryDisplayResolutionVertical -> Can consider binning
Census_InternalBatteryNumberOfCharges -> Can consider binning
Census_OSBuildNumber -> Can consider removing rare records
Census_OSBuildRevision -> Can consider removing rare records
Census_OSInstallLanguageIdentifier -> Ok
Census_OSUILocaleIdentifier -> Can consider removing rare records
Census_IsPortableOperatingSystem -> Can remove this column (Binary) V v skewed distribution
Census_IsFlightingInternal -> Can remove this column (Binary) V v skewed distribution
Census_IsFlightsDisabled -> Can remove this column (Binary) V v skewed distribution
Census_ThresholdOptIn -> Can remove this column (Binary) V v skewed distribution
Census_FirmwareManufacturerIdentifier -> Can consider removing rare records
Census_FirmwareVersionIdentifier -> Can consider removing rare records
Census_IsSecureBootEnabled -> Ok (Binary)
Census_IsWIMBootEnabled ->  Can remove this column (Binary) V v skewed distribution
Census_IsVirtualDevice -> Can remove this column (Binary)
Census_IsTouchEnabled -> Ok (Binary)
Census_IsPenCapable -> Ok (Binary)
Census_IsAlwaysOnAlwaysConnectedCapable -> Ok (Binary)
Wdft_IsGamer -> Ok (Binary)
Wdft_RegionIdentifier -> Ok
'''

for col in non_obj_cols:
    show_value_counts(col)
# Out:
# IsBeta
# 0    5354414
# 1          1
# Name: count, dtype: int64
# IsBeta
# 0    4416597
# Name: count, dtype: int64
# RtpStateBitfield
# 7.0     5185421
# 0.0      120043
# 5.0       14928
# 8.0       13430
# 3.0        2396
# 1.0         751
# 35.0         15
# Name: count, dtype: int64
# RtpStateBitfield
# 7.0     4280454
# 0.0       96939
# 8.0       12480
# 5.0        9044
# 3.0        1440
# 1.0         523
# 35.0         13
# Name: count, dtype: int64
# IsSxsPassiveMode
# 0    5248992
# 1     105423
# Name: count, dtype: int64
# IsSxsPassiveMode
# 0    4335802
# 1      80795
# Name: count, dtype: int64
# DefaultBrowsersIdentifier
# 3196.0    28256
# 239.0     26273
# 1632.0    24179
# 3176.0    19005
# 146.0     13641
#           ...
# 1783.0        1
# 383.0         1
# 993.0         1
# 2744.0        1
# 1149.0        1
# Name: count, Length: 1329, dtype: int64
# DefaultBrowsersIdentifier
# 239.0     22057
# 3196.0    19592
# 1632.0    13498
# 3176.0    10412
# 146.0      8734
#           ...
# 247.0         1
# 2308.0        1
# 2210.0        1
# 2616.0        1
# 391.0         1
# Name: count, Length: 1129, dtype: int64
# AVProductStatesIdentifier
# 53447.0    3196572
# 7945.0      310178
# 47238.0     309320
# 62773.0     154814
# 46413.0     108338
#             ...
# 66242.0          1
# 33518.0          1
# 18052.0          1
# 37424.0          1
# 31745.0          1
# Name: count, Length: 21764, dtype: int64
# AVProductStatesIdentifier
# 53447.0    2800102
# 47238.0     285191
# 7945.0      182518
# 62773.0     141310
# 46413.0      75289
#             ...
# 52159.0          1
# 23965.0          1
# 3415.0           1
# 68452.0          1
# 41175.0          1
# Name: count, Length: 17648, dtype: int64
# AVProductsInstalled
# 1.0    3370844
# 2.0    1788089
# 3.0     172699
# 4.0       7285
# 5.0        393
# 6.0         24
# 0.0          1
# Name: count, dtype: int64
# AVProductsInstalled
# 1.0    2959301
# 2.0    1325750
# 3.0     118341
# 4.0       5117
# 5.0        260
# 6.0         17
# Name: count, dtype: int64
# AVProductsEnabled
# 1.0    5218135
# 2.0     105368
# 0.0      11970
# 3.0       3525
# 4.0        319
# 5.0         18
# Name: count, dtype: int64
# AVProductsEnabled
# 1.0    4320148
# 2.0      77284
# 0.0       8131
# 3.0       2935
# 4.0        273
# 5.0         15
# Name: count, dtype: int64
# HasTpm
# 1    5347675
# 0       6740
# Name: count, dtype: int64
# HasTpm
# 1    4412023
# 0       4574
# Name: count, dtype: int64
# CountryIdentifier
# 141    223069
# 29     205636
# 43     204263
# 171    165679
# 93     164810
#         ...
# 165       160
# 37        130
# 193       128
# 186       107
# 217        59
# Name: count, Length: 222, dtype: int64
# CountryIdentifier
# 43     227896
# 141    193188
# 171    174229
# 29     168393
# 60     132790
#         ...
# 217       138
# 165       134
# 186       120
# 37        120
# 161        86
# Name: count, Length: 222, dtype: int64
# CityIdentifier
# 130775.0    62941
# 82373.0     59018
# 16668.0     58500
# 143782.0    42034
# 10222.0     41791
#             ...
# 95242.0         1
# 153886.0        1
# 24526.0         1
# 30786.0         1
# 97837.0         1
# Name: count, Length: 93050, dtype: int64
# CityIdentifier
# 82373.0     46143
# 130775.0    44518
# 16668.0     39334
# 66202.0     37879
# 10222.0     34786
#             ...
# 117003.0        1
# 45366.0         1
# 158409.0        1
# 136962.0        1
# 25296.0         1
# Name: count, Length: 89995, dtype: int64
# OrganizationIdentifier
# 27.0    2605305
# 18.0    1050866
# 48.0      33322
# 50.0      21197
# 11.0      11482
# 37.0      10637
# 49.0       8910
# 46.0       6119
# 14.0       2851
# 52.0       1894
# 32.0       1881
# 36.0       1666
# 33.0       1480
# 2.0        1248
# 5.0         912
# 28.0        615
# 4.0         579
# 20.0        495
# 1.0         451
# 10.0        415
# 40.0        370
# 8.0         367
# 51.0        348
# 21.0        281
# 39.0        203
# 3.0         187
# 22.0        183
# 6.0         161
# 47.0        152
# 31.0        133
# 16.0        104
# 26.0         95
# 19.0         70
# 29.0         64
# 42.0         60
# 44.0         54
# 7.0          39
# 45.0         39
# 43.0         32
# 30.0         31
# 41.0         20
# 35.0         20
# 15.0          7
# 25.0          7
# 23.0          6
# 12.0          3
# 34.0          2
# 17.0          1
# Name: count, dtype: int64
# OrganizationIdentifier
# 27.0    2116601
# 18.0     866593
# 48.0      38332
# 50.0      19033
# 11.0       9467
# 37.0       8526
# 49.0       7425
# 46.0       5334
# 14.0       1907
# 32.0       1669
# 52.0       1483
# 36.0       1376
# 33.0       1219
# 2.0         986
# 5.0         824
# 28.0        654
# 4.0         591
# 38.0        559
# 20.0        556
# 1.0         486
# 51.0        437
# 8.0         424
# 10.0        320
# 40.0        308
# 22.0        192
# 39.0        154
# 6.0         145
# 47.0        130
# 3.0         113
# 16.0        112
# 31.0         94
# 21.0         91
# 19.0         87
# 44.0         66
# 29.0         59
# 7.0          48
# 30.0         43
# 26.0         40
# 42.0         37
# 41.0         37
# 43.0         29
# 45.0         24
# 35.0         20
# 12.0          5
# 23.0          4
# 15.0          3
# 34.0          3
# 9.0           1
# 25.0          1
# 13.0          1
# Name: count, dtype: int64
# GeoNameIdentifier
# 277.0    715776
# 211.0    241952
# 167.0    233127
# 53.0     215480
# 240.0    214154
#           ...
# 132.0         1
# 51.0          1
# 13.0          1
# 197.0         1
# 55.0          1
# Name: count, Length: 290, dtype: int64
# GeoNameIdentifier
# 277.0    610924
# 211.0    247633
# 53.0     235555
# 167.0    198847
# 240.0    178381
#           ...
# 116.0         1
# 14.0          1
# 210.0         1
# 219.0         1
# 83.0          1
# Name: count, Length: 287, dtype: int64
# LocaleEnglishNameIdentifier
# 75     1062400
# 182     262401
# 74      259498
# 227     227704
# 88      221054
#         ...
# 190          2
# 191          1
# 153          1
# 39           1
# 137          1
# Name: count, Length: 273, dtype: int64
# LocaleEnglishNameIdentifier
# 75     918718
# 182    265264
# 42     236834
# 74     202421
# 227    194280
#         ...
# 146         1
# 39          1
# 256         1
# 264         1
# 193         1
# Name: count, Length: 270, dtype: int64
# OsBuild
# 17134    2168701
# 16299    1691661
# 15063     569034
# 14393     531685
# 10586     283697
# 10240     101458
# 17692       1451
# 17738        996
# 17744        991
# 17758        551
# 17713        473
# 17746        458
# 17754        391
# 17751        359
# 17735        336
# 17741        289
# 17755        267
# 17686        248
# 17763        225
# 17733        200
# 17760        186
# 17672        151
# 17677        123
# 17682        119
# 17666         61
# 17661         58
# 18234         45
# 18237         31
# 17730         21
# 17650         21
# 18242         21
# 17711         13
# 17704         13
# 17627         12
# 17639         11
# 17723         11
# 17728         10
# 18219          8
# 17634          7
# 17655          6
# 17643          5
# 18204          4
# 18214          2
# 17604          2
# 17618          1
# 17753          1
# 17756          1
# Name: count, dtype: int64
# OsBuild
# 17134    2082518
# 16299    1088916
# 15063     413447
# 14393     385753
# 10586     225889
# 17763     126527
# 10240      88095
# 18252       1357
# 17758       1210
# 18282        408
# 18262        321
# 17744        262
# 18272        239
# 18277        168
# 17754        165
# 18267        161
# 17760        156
# 17692        146
# 17738        108
# 17751         77
# 17686         76
# 17672         61
# 17746         58
# 18247         51
# 17677         48
# 17713         46
# 18242         40
# 17755         40
# 17682         38
# 17661         28
# 17741         25
# 17666         25
# 17735         20
# 18234         15
# 17733         15
# 17634         15
# 18237         13
# 17650         12
# 17639         12
# 17627          7
# 17655          5
# 17723          5
# 17643          4
# 17711          3
# 17704          3
# 18219          2
# 18214          2
# 17623          1
# 17618          1
# 17728          1
# 18204          1
# 17730          1
# Name: count, dtype: int64
# OsSuite
# 768    5354216
# 784        198
# 528          1
# Name: count, dtype: int64
# OsSuite
# 768    4416394
# 784        201
# 256          2
# Name: count, dtype: int64
# IsProtected
# 1.0    5027731
# 0.0     311607
# Name: count, dtype: int64
# IsProtected
# 1.0    4141218
# 0.0     267571
# Name: count, dtype: int64
# AutoSampleOptIn
# 0    5354277
# 1        138
# Name: count, dtype: int64
# AutoSampleOptIn
# 0    4416536
# 1         61
# Name: count, dtype: int64
# SMode
# 0.0    4992849
# 1.0       2311
# Name: count, dtype: int64
# SMode
# 0.0    1215070
# 1.0       4384
# Name: count, dtype: int64
# IeVerIdentifier
# 137.0    2154070
# 117.0    1235699
# 108.0     357740
# 111.0     300403
# 98.0      258672
#           ...
# 2.0            1
# 333.0          1
# 140.0          1
# 297.0          1
# 184.0          1
# Name: count, Length: 103, dtype: int64
# IeVerIdentifier
# 137.0    2069962
# 117.0     749760
# 108.0     266868
# 111.0     233425
# 98.0      199989
#           ...
# 315.0          1
# 337.0          1
# 173.0          1
# 140.0          1
# 174.0          1
# Name: count, Length: 107, dtype: int64
# Firewall
# 1.0    5274759
# 0.0      73839
# Name: count, dtype: int64
# Firewall
# 1.0    4352973
# 0.0      59333
# Name: count, dtype: int64
# UacLuaenable
# 1.0           5332693
# 0.0             15178
# 48.0               89
# 2.0                29
# 49.0               15
# 3.0                 4
# 6357062.0           2
# 16777216.0          1
# 5.0                 1
# 7798884.0           1
# Name: count, dtype: int64
# UacLuaenable
# 1.0            4397143
# 0.0              14826
# 48.0                83
# 2.0                 17
# 49.0                11
# 6357062.0            4
# 3.0                  4
# 808482880.0          1
# 537591872.0          1
# Name: count, dtype: int64
# Census_OEMNameIdentifier
# 2668.0    843163
# 2102.0    824046
# 585.0     682554
# 525.0     679770
# 2206.0    475322
#            ...
# 2040.0         1
# 696.0          1
# 5652.0         1
# 2660.0         1
# 4460.0         1
# Name: count, Length: 1819, dtype: int64
# Census_OEMNameIdentifier
# 2668.0    693990
# 2102.0    690469
# 525.0     572009
# 585.0     535586
# 1443.0    380922
#            ...
# 352.0          1
# 4352.0         1
# 316.0          1
# 3690.0         1
# 948.0          1
# Name: count, Length: 1760, dtype: int64
# Census_OEMModelIdentifier
# 242491.0    240925
# 313586.0     94055
# 228975.0     64650
# 245824.0     64428
# 241876.0     61285
#              ...
# 320465.0         1
# 9702.0           1
# 248143.0         1
# 276692.0         1
# 247716.0         1
# Name: count, Length: 86548, dtype: int64
# Census_OEMModelIdentifier
# 242491.0    171289
# 313586.0     82423
# 241876.0     50871
# 228975.0     49264
# 245824.0     45378
#              ...
# 288356.0         1
# 100711.0         1
# 235933.0         1
# 111788.0         1
# 184934.0         1
# Name: count, Length: 82349, dtype: int64
# Census_ProcessorCoreCount
# 4.0     3337782
# 2.0     1423049
# 8.0      480903
# 12.0      43332
# 6.0       26567
# 1.0       16250
# 16.0       5271
# 3.0        3916
# 20.0        258
# 32.0        160
# 24.0         65
# 5.0          43
# 36.0         41
# 28.0         32
# 7.0          28
# 64.0          8
# 14.0          4
# 10.0          3
# 40.0          2
# 44.0          2
# 18.0          2
# Name: count, dtype: int64
# Census_ProcessorCoreCount
# 4.0     2657604
# 2.0     1180436
# 8.0      454440
# 12.0      53136
# 6.0       27050
# 1.0       13511
# 16.0       5799
# 3.0        3345
# 20.0        257
# 32.0        127
# 24.0        102
# 5.0          39
# 36.0         35
# 28.0         35
# 7.0          29
# 64.0         20
# 10.0          3
# 48.0          2
# 44.0          2
# 9.0           2
# 14.0          1
# Name: count, dtype: int64
# Census_ProcessorManufacturerIdentifier
# 5.0     4669727
# 1.0      667919
# 3.0          54
# 10.0         18
# Name: count, dtype: int64
# Census_ProcessorManufacturerIdentifier
# 5.0     3847552
# 1.0      548366
# 3.0          45
# 10.0         10
# Name: count, dtype: int64
# Census_ProcessorModelIdentifier
# 1998.0    237014
# 2696.0    214565
# 1992.0    155731
# 2660.0    147201
# 2372.0    141924
#            ...
# 503.0          1
# 1020.0         1
# 1195.0         1
# 3832.0         1
# 2154.0         1
# Name: count, Length: 1912, dtype: int64
# Census_ProcessorModelIdentifier
# 1998.0    191945
# 2696.0    168789
# 1992.0    124011
# 2736.0    113246
# 2382.0    108751
#            ...
# 3806.0         1
# 175.0          1
# 2370.0         1
# 1896.0         1
# 3896.0         1
# Name: count, Length: 1918, dtype: int64
# Census_PrimaryDiskTotalCapacity
# 476940.0     1738473
# 953869.0     1569365
# 29820.0       284032
# 122104.0      282678
# 244198.0      237090
#               ...
# 143051.0           1
# 1907697.0          1
# 463063.0           1
# 3815298.0          1
# 107196.0           1
# Name: count, Length: 1180, dtype: int64
# Census_PrimaryDiskTotalCapacity
# 476940.0    1376013
# 953869.0    1252921
# 122104.0     256126
# 29820.0      250882
# 244198.0     211950
#              ...
# 954107.0          1
# 427347.0          1
# 231199.0          1
# 69043.0           1
# 68902.0           1
# Name: count, Length: 1198, dtype: int64
# Census_SystemVolumeTotalCapacity
# 926992.0    49547
# 28542.0     47209
# 952728.0    37357
# 952727.0    32960
# 952792.0    32252
#             ...
# 853060.0        1
# 419133.0        1
# 57555.0         1
# 884158.0        1
# 637127.0        1
# Name: count, Length: 440097, dtype: int64
# Census_SystemVolumeTotalCapacity
# 926992.0    41213
# 28542.0     40965
# 953253.0    32219
# 476324.0    29078
# 952728.0    26973
#             ...
# 240876.0        1
# 607127.0        1
# 705646.0        1
# 705601.0        1
# 72462.0         1
# Name: count, Length: 408437, dtype: int64
# Census_HasOpticalDiskDrive
# 0    4986836
# 1     367579
# Name: count, dtype: int64
# Census_HasOpticalDiskDrive
# 0    4147988
# 1     268609
# Name: count, dtype: int64
# Census_TotalPhysicalRAM
# 4096.0     2581743
# 8192.0     1252272
# 2048.0      720130
# 6144.0      266419
# 16384.0     257872
#             ...
# 12279.0          1
# 4054.0           1
# 4056.0           1
# 3787.0           1
# 12264.0          1
# Name: count, Length: 585, dtype: int64
# Census_TotalPhysicalRAM
# 4096.0     2105820
# 8192.0     1052323
# 2048.0      590538
# 16384.0     223936
# 6144.0      210522
#             ...
# 8172.0           1
# 2910.0           1
# 1926.0           1
# 3543.0           1
# 16315.0          1
# Name: count, Length: 597, dtype: int64
# Census_InternalPrimaryDiagonalDisplaySizeInInches
# 15.500000    2208975
# 13.898438     710073
# 14.000000     288288
# 11.601562     257103
# 13.203125     142009
#               ...
# 80.812500          1
# 72.812500          1
# 75.812500          1
# 67.187500          1
# 53.187500          1
# Name: count, Length: 660, dtype: int64
# Census_InternalPrimaryDiagonalDisplaySizeInInches
# 15.500000    1816216
# 13.898438     592612
# 14.000000     221291
# 11.601562     218154
# 13.203125     112812
#               ...
# 40.312500          1
# 64.000000          1
# 94.875000          1
# 37.812500          1
# 62.812500          1
# Name: count, Length: 653, dtype: int64
# Census_InternalPrimaryDisplayResolutionHorizontal
# 1366.0    3094999
# 1920.0    1317446
# 1600.0     279261
# 1280.0     258707
# 1024.0     117008
#            ...
# 1936.0          1
# 1516.0          1
# 1298.0          1
# 1780.0          1
# 1138.0          1
# Name: count, Length: 233, dtype: int64
# Census_InternalPrimaryDisplayResolutionHorizontal
# 1366.0    2490712
# 1920.0    1148352
# 1600.0     223330
# 1280.0     206442
# 1024.0     101697
#            ...
# 1226.0          1
# 1700.0          1
# 5432.0          1
# 1085.0          1
# 5888.0          1
# Name: count, Length: 246, dtype: int64
# Census_InternalPrimaryDisplayResolutionVertical
# 768.0     3267363
# 1080.0    1278837
# 900.0      323848
# 800.0      164915
# 1024.0      51191
#            ...
# 667.0           1
# 1023.0          1
# 882.0           1
# 1005.0          1
# 580.0           1
# Name: count, Length: 186, dtype: int64
# Census_InternalPrimaryDisplayResolutionVertical
# 768.0     2636831
# 1080.0    1118089
# 900.0      263340
# 800.0      129849
# 1024.0      44404
#            ...
# 808.0           1
# 920.0           1
# 322.0           1
# 1183.0          1
# 1382.0          1
# Name: count, Length: 187, dtype: int64
# Census_InternalBatteryNumberOfCharges
# 0.000000e+00    3377727
# 4.294967e+09     852237
# 1.000000e+00      40613
# 1.600000e+01      22871
# 2.000000e+00      20299
#                  ...
# 1.906900e+04          1
# 3.512000e+03          1
# 2.826000e+03          1
# 1.513800e+04          1
# 1.680700e+04          1
# Name: count, Length: 40008, dtype: int64
# Census_InternalBatteryNumberOfCharges
# 0.000000e+00    2761675
# 4.294967e+09     734613
# 1.000000e+00      36612
# 1.600000e+01      18551
# 2.000000e+00      18096
#                  ...
# 3.036400e+04          1
# 3.366400e+04          1
# 6.373100e+04          1
# 1.494600e+04          1
# 1.135100e+04          1
# Name: count, Length: 35120, dtype: int64
# Census_OSBuildNumber
# 17134    2224793
# 16299    1641622
# 15063     567398
# 14393     528361
# 10586     282834
#           ...
# 17618          1
# 17711          1
# 14936          1
# 7601           1
# 16241          1
# Name: count, Length: 64, dtype: int64
# Census_OSBuildNumber
# 17134    2138624
# 16299    1036813
# 15063     412101
# 14393     382608
# 10586     224834
#           ...
# 16179          1
# 14422          1
# 14216          1
# 17742          1
# 17127          1
# Name: count, Length: 65, dtype: int64
# Census_OSBuildRevision
# 228      775659
# 165      488465
# 431      396370
# 285      262901
# 547      249790
#           ...
# 18687         1
# 1797          1
# 17446         1
# 17617         1
# 601           1
# Name: count, Length: 230, dtype: int64
# Census_OSBuildRevision
# 345     752585
# 285     382216
# 407     236290
# 431     207023
# 286     206110
#          ...
# 2395         1
# 111          1
# 491          1
# 373          1
# 1670         1
# Name: count, Length: 244, dtype: int64
# Census_OSInstallLanguageIdentifier
# 8.0     1803369
# 9.0      676859
# 7.0      313057
# 29.0     284795
# 10.0     270203
# 14.0     262090
# 37.0     214767
# 26.0     196683
# 5.0      150424
# 39.0     133975
# 35.0     128818
# 18.0     119491
# 20.0      98554
# 24.0      90685
# 25.0      86348
# 27.0      75394
# 1.0       51363
# 3.0       46818
# 19.0      45775
# 17.0      37285
# 6.0       35635
# 33.0      33473
# 15.0      26271
# 4.0       24082
# 30.0      21939
# 23.0      21131
# 12.0      13549
# 31.0      12266
# 16.0       9210
# 28.0       8454
# 36.0       7615
# 2.0        7467
# 34.0       6755
# 13.0       6162
# 21.0       4603
# 32.0       3436
# 22.0       2235
# 38.0       2195
# 11.0       1908
# Name: count, dtype: int64
# Census_OSInstallLanguageIdentifier
# 8.0     1462721
# 9.0      519519
# 29.0     293382
# 7.0      245726
# 37.0     234593
# 10.0     223484
# 14.0     200435
# 26.0     161909
# 35.0     120151
# 5.0      110192
# 39.0      99603
# 18.0      98136
# 25.0      91128
# 20.0      87139
# 24.0      59870
# 27.0      58350
# 1.0       46509
# 19.0      35318
# 3.0       34913
# 17.0      28798
# 6.0       27407
# 33.0      21680
# 15.0      19538
# 30.0      17263
# 4.0       14988
# 23.0      13178
# 12.0      10766
# 31.0       9788
# 36.0       8377
# 28.0       7632
# 16.0       7381
# 2.0        6357
# 34.0       6325
# 13.0       4411
# 21.0       3656
# 32.0       3047
# 22.0       1859
# 11.0       1624
# 38.0       1523
# Name: count, dtype: int64
# Census_OSUILocaleIdentifier
# 31     1788275
# 34      679014
# 30      313454
# 125     287388
# 35      277476
#         ...
# 14           1
# 22           1
# 33           1
# 134          1
# 104          1
# Name: count, Length: 129, dtype: int64
# Census_OSUILocaleIdentifier
# 31     1449887
# 34      521296
# 125     295972
# 30      246141
# 158     236128
#         ...
# 46           1
# 3            1
# 150          1
# 101          1
# 1            1
# Name: count, Length: 126, dtype: int64
# Census_IsPortableOperatingSystem
# 0    5352942
# 1       1473
# Name: count, dtype: int64
# Census_IsPortableOperatingSystem
# 0    4415112
# 1       1485
# Name: count, dtype: int64
# Census_IsFlightingInternal
# 0.0    829749
# 1.0         2
# Name: count, dtype: int64
# Census_IsFlightingInternal
# 0.0    609791
# 1.0         1
# Name: count, dtype: int64
# Census_IsFlightsDisabled
# 0.0    5331305
# 1.0         22
# Name: count, dtype: int64
# Census_IsFlightsDisabled
# 0.0    4393907
# 1.0          4
# Name: count, dtype: int64
# Census_ThresholdOptIn
# 0.0    1959967
# 1.0        175
# Name: count, dtype: int64
# Census_ThresholdOptIn
# 0.0    1358582
# 1.0        156
# Name: count, dtype: int64
# Census_FirmwareManufacturerIdentifier
# 142.0    1566659
# 554.0     977102
# 628.0     794417
# 556.0     639236
# 355.0     454468
#           ...
# 53.0           1
# 250.0          1
# 952.0          1
# 631.0          1
# 638.0          1
# Name: count, Length: 479, dtype: int64
# Census_FirmwareManufacturerIdentifier
# 142.0    1310976
# 554.0     794550
# 628.0     654259
# 556.0     500440
# 355.0     378503
#           ...
# 28.0           1
# 574.0          1
# 130.0          1
# 655.0          1
# 407.0          1
# Name: count, Length: 493, dtype: int64
# Census_FirmwareVersionIdentifier
# 33105.0    74966
# 33111.0    51505
# 33054.0    49182
# 33108.0    44520
# 63175.0    44087
#            ...
# 2418.0         1
# 23193.0        1
# 68380.0        1
# 30653.0        1
# 69704.0        1
# Name: count, Length: 35204, dtype: int64
# Census_FirmwareVersionIdentifier
# 33105.0    58524
# 33054.0    45257
# 33111.0    37510
# 33000.0    34710
# 33108.0    33991
#            ...
# 28015.0        1
# 71532.0        1
# 34311.0        1
# 38294.0        1
# 63955.0        1
# Name: count, Length: 34844, dtype: int64
# Census_IsSecureBootEnabled
# 1    3568869
# 0    1785546
# Name: count, dtype: int64
# Census_IsSecureBootEnabled
# 1    2872867
# 0    1543730
# Name: count, dtype: int64
# Census_IsWIMBootEnabled
# 0.0    1963905
# 1.0          1
# Name: count, dtype: int64
# Census_IsWIMBootEnabled
# 0.0    1361993
# 1.0          1
# Name: count, dtype: int64
# Census_IsVirtualDevice
# 0.0    5345322
# Name: count, dtype: int64
# Census_IsVirtualDevice
# 0.0    4407704
# Name: count, dtype: int64
# Census_IsTouchEnabled
# 0    4547442
# 1     806973
# Name: count, dtype: int64
# Census_IsTouchEnabled
# 0    3767220
# 1     649377
# Name: count, dtype: int64
# Census_IsPenCapable
# 0    5193591
# 1     160824
# Name: count, dtype: int64
# Census_IsPenCapable
# 0    4275021
# 1     141576
# Name: count, dtype: int64
# Census_IsAlwaysOnAlwaysConnectedCapable
# 0.0    4953748
# 1.0     369738
# Name: count, dtype: int64
# Census_IsAlwaysOnAlwaysConnectedCapable
# 0.0    4078583
# 1.0     305340
# Name: count, dtype: int64
# Wdft_IsGamer
# 0.0    3699990
# 1.0    1494638
# Name: count, dtype: int64
# Wdft_IsGamer
# 0.0    3001738
# 1.0    1278595
# Name: count, dtype: int64
# Wdft_RegionIdentifier
# 10.0    1224164
# 1.0      736444
# 11.0     733512
# 3.0      725799
# 15.0     652322
# 7.0      337733
# 8.0      161092
# 5.0      128440
# 13.0     126695
# 12.0     104818
# 6.0       89271
# 4.0       82266
# 2.0       47850
# 9.0       42471
# 14.0       1751
# Name: count, dtype: int64
# Wdft_RegionIdentifier
# 10.0    947782
# 3.0     659588
# 11.0    616678
# 1.0     615120
# 15.0    486228
# 7.0     323125
# 8.0     125044
# 13.0    114052
# 5.0     102816
# 12.0     80370
# 6.0      71118
# 4.0      57586
# 2.0      38652
# 9.0      32836
# 14.0      9338
# Name: count, dtype: int64
# HasDetections
# 0    2713221
# 1    2641194
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HasDetections'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 57
#       1 '''
#       2 IsBeta -> Can remove this column (Binary) V v skewed distribution
#       3 RtpStateBitfield -> Ok. (Categorical)
#    (...)
#      53 Wdft_RegionIdentifier -> Ok
#      54 '''
#      56 for col in non_obj_cols:
# ---> 57     show_value_counts(col)
#
# Cell In[6], line 3, in show_value_counts(col)
#       1 def show_value_counts(col):
#       2     print(train_filtered[col].value_counts())
# ----> 3     print(test_filtered[col].value_counts())
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'HasDetections'

# %%
disk_type_remap = {'HDD' : 'HDD',
                   'SSD' : 'SDD',
                   'UNKNOWN' : 'Unknown',
                   'Unspecified' : 'Unknown'
                  }

show_value_counts('Census_PrimaryDiskTypeName')
remap_col('Census_PrimaryDiskTypeName', disk_type_remap)
show_value_counts('Census_PrimaryDiskTypeName')

# %% [markdown]
# ### 3. Remove the Rare Records (Optional)

# %%
# To consider
'''
ProductName -> Can consider to remove the rare records
EngineVersion -> Can consider to remove the rare records
AppVersion -> Can consider to remove the rare records
AvSigVersion -> Can consider to remove the rare records
Processor -> Can consider to remove the rare records (arm64)
OsBuildLab -> Can consider to remove the rare records
Census_DeviceFamily -> Can consider to remove the rare records
Census_OSVersion -> Can consider to remove the rare records
Census_OSArchitecture -> Can consider to remove the rare records
Census_OSBranch -> Can consider to remove the rare records
Census_FlightRing -> Can consider to remove the rare records
IsBeta -> Can remove this column (Binary) V v skewed distribution
DefaultBrowsersIdentifier -> Can consider removing rare records
AVProductStatesIdentifier -> Can consider removing rare records
CityIdentifier -> Can consider removing rare records
OrganizationIdentifier -> Can consider removing rare records
GeoNameIdentifier -> Can consider removing rare records
LocaleEnglishNameIdentifier -> Can consider removing rare records
OsBuild -> Can consider removing rare records
IeVerIdentifier -> Can consider removing rare records
UacLuaenable -> Can consider removing rare records 
Census_OEMNameIdentifier -> Can consider removing rare records
Census_OEMModelIdentifier -> Can consider removing rare records
Census_ProcessorCoreCount -> Can consider binning
Census_ProcessorManufacturerIdentifier -> Can consider removing rare records
Census_ProcessorModelIdentifier -> Can consider removing rare records
Census_OSBuildNumber -> Can consider removing rare records
Census_OSBuildRevision -> Can consider removing rare records
Census_OSUILocaleIdentifier -> Can consider removing rare records
Census_FirmwareManufacturerIdentifier -> Can consider removing rare records
Census_FirmwareVersionIdentifier -> Can consider removing rare records
'''

# %% [markdown]
# ### 4. Binning (Optional)

# %%
# To consider
'''
Census_InternalPrimaryDiagonalDisplaySizeInInches -> Can consider binning
Census_InternalPrimaryDisplayResolutionHorizontal -> Can consider binning
Census_InternalPrimaryDisplayResolutionVertical -> Can consider binning
Census_InternalBatteryNumberOfCharges -> Can consider binning
Census_PrimaryDiskTotalCapacity -> Can consider binning
Census_SystemVolumeTotalCapacity -> Can consider binning
Census_ProcessorCoreCount -> Can consider binning
'''

# %% [markdown]
# ### 5. To Remove (To Decide)
# Criteria: <br>
# (1) Either very skewed <br>
# (2) Lots of Nulls <br>
# (3) ID columns (useless)

# %%
'''
# Uncontroversial
MachineIdentifier -> Can ignore its just id
Platform -> Useless cause we filtered this to only Win10
OsVer -> Useless cause we filtered this to only Win10
SkuEdition -> Useless
IsBeta -> Can remove this column (Binary) V v skewed distribution
OsSuite -> Can remove this column -> V v skewed distribution

# More Controversial
PuaMode -> Lots of nulls
AutoSampleOptIn -> Can remove this column (Binary) V v skewed distribution
SMode -> Can remove this column (Binary) V v skewed distribution
Census_IsPortableOperatingSystem -> Can remove this column (Binary) V v skewed distribution
Census_IsFlightingInternal -> Can remove this column (Binary) V v skewed distribution
Census_IsFlightsDisabled -> Can remove this column (Binary) V v skewed distribution
Census_ThresholdOptIn -> Can remove this column (Binary) V v skewed distribution
Census_IsWIMBootEnabled ->  Can remove this column (Binary) V v skewed distribution
'''

# %%
train_filtered.to_csv('train_filtered.csv', index=False)
test_filtered.to_csv('test_filtered.csv', index=False)
